# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile

# Replace 'file.zip' with the name of your zip file
zip_file_path = '/content/drive/MyDrive/Disease Prediction.zip'

# Replace '/path/to/extract' with the directory where you want to extract the contents
extract_to = '/content/drive/MyDrive/Disease Prediction Folder'

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extract_to)

print("Extraction completed.")
# Out:
# Extraction completed.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import xgboost as xgb
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the data
train_data = pd.read_csv('/content/drive/MyDrive/Disease Prediction Folder/Disease Prediction/Train_data.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Disease Prediction Folder/Disease Prediction/test_data.csv')

# %%
train_data.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.739597     0.650198    0.713631   0.868491           0.687433
# 1  0.121786     0.023058    0.944893   0.905372           0.507711
# 2  0.452539     0.116135    0.544560   0.400640           0.294538
# 3  0.136609     0.015605    0.419957   0.191487           0.081168
# 4  0.176737     0.752220    0.971779   0.785286           0.443880
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.529895    0.290006                 0.631045
# 1         0.403033    0.164216                 0.307553
# 2         0.382021    0.625267                 0.295122
# 3         0.166214    0.073293                 0.668719
# 4         0.439851    0.894991                 0.442159
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.001328                                   0.795829
# ...

# %%
train_data.shape
# Out:
# (2351, 25)

# %%
test_data.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.001827     0.033693    0.114755   0.997927           0.562604
# 1  0.436679     0.972653    0.084998   0.180909           0.675736
# 2  0.545697     0.324815    0.584467   0.475748           0.558596
# 3  0.172994     0.050351    0.736000   0.782022           0.069435
# 4  0.758534     0.739968    0.597868   0.772683           0.875720
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.866499    0.578042                 0.914615
# 1         0.563889    0.798382                 0.670361
# 2         0.661007    0.934056                 0.381782
# 3         0.085219    0.032907                 0.460619
# 4         0.860265    0.486189                 0.486686
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.026864                                   0.038641
# ...

# %%
test_data.shape
# Out:
# (486, 25)

# %%
# Convert the 'Disease' column to numeric
train_data['Disease'] = train_data['Disease'].map({'Healthy': 0, 'Diabetes': 1, 'Thalasse': 1, 'Anemia': 1})

# Split the data into features (X) and target (y)
X_train = train_data.drop('Disease', axis=1)
y_train = train_data['Disease']

# %%
# Drop rows with missing values in y_train
X_train = X_train[~y_train.isnull()]
y_train = y_train[~y_train.isnull()]

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (2228, 24)
# (2228,)

# %%
train_data.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.739597     0.650198    0.713631   0.868491           0.687433
# 1  0.121786     0.023058    0.944893   0.905372           0.507711
# 2  0.452539     0.116135    0.544560   0.400640           0.294538
# 3  0.136609     0.015605    0.419957   0.191487           0.081168
# 4  0.176737     0.752220    0.971779   0.785286           0.443880
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.529895    0.290006                 0.631045
# 1         0.403033    0.164216                 0.307553
# 2         0.382021    0.625267                 0.295122
# 3         0.166214    0.073293                 0.668719
# 4         0.439851    0.894991                 0.442159
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.001328                                   0.795829
# ...

# %%
# # Convert the 'Disease' column to numeric
test_data['Disease'] = test_data['Disease'].map({'Healthy': 0, 'Diabetes': 1, 'Thalasse': 1, 'Anemia': 1})

# Drop rows with NaN values in the 'Disease' column for test data
test_data = test_data.dropna(subset=['Disease'])

# Reset the index of the test data to avoid mismatch with boolean indexing
test_data.reset_index(drop=True, inplace=True)

# Split the test data into features (X_test) and target (y_test)
X_test = test_data.drop('Disease', axis=1)
y_test = test_data['Disease']

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (431, 24)
# (431,)

# %%
test_data.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.001827     0.033693    0.114755   0.997927           0.562604
# 1  0.436679     0.972653    0.084998   0.180909           0.675736
# 2  0.172994     0.050351    0.736000   0.782022           0.069435
# 3  0.677636     0.435037    0.572571   0.965847           0.010580
# 4  0.105103     0.177558    0.169041   0.679138           0.886839
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.866499    0.578042                 0.914615
# 1         0.563889    0.798382                 0.670361
# 2         0.085219    0.032907                 0.460619
# 3         0.753719    0.262138                 0.789804
# 4         0.714977    0.197501                 0.778653
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.026864                                   0.038641
# ...

# %%
# Feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ###### LOGISTIC REGRESSION MODEL

# %%
# Create an instance of the Logistic Regression model
log_reg = LogisticRegression()

# Train the model on the training data
log_reg.fit(X_train, y_train)

# Make predictions on the test data
y_pred = log_reg.predict(X_test)

# %%
# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# %%
print("\nTest Set Performance:")
print(f"Accuracy: {accuracy:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1-score: {f1:.3f}")
print(f"ROC_AUC: {roc_auc:.3f}")
# Out:
# Test Set Performance:
# Accuracy: 0.680
# Precision: 0.997
# Recall: 0.678
# F1-score: 0.807
# ROC_AUC: 0.739

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(y_test, y_pred, title):
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(3, 3))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Reds", cbar=False)
    plt.title(title)
    plt.xlabel("Predicted labels")
    plt.ylabel("True labels")
    plt.show()

# Plot confusion matrix for Random Forest
plot_confusion_matrix(y_test, y_pred, title="Logistic Regression Confusion Matrix")

# %% [markdown]
# ###### RANDOM FOREST MODEL

# %%
# Create an instance of the Random Forest model
random_forest = RandomForestClassifier()

# Train the model on the training data
random_forest.fit(X_train, y_train)

# Make predictions on the test data
y_pred = random_forest.predict(X_test)

# %%
# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# %%
print("\nTest Set Performance:")
print(f"Accuracy: {accuracy:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1-score: {f1:.3f}")
print(f"ROC_AUC: {roc_auc:.3f}")
# Out:
# Test Set Performance:
# Accuracy: 0.942
# Precision: 0.993
# Recall: 0.948
# F1-score: 0.970
# ROC_AUC: 0.674

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(y_test, y_pred, title):
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(3, 3))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Greens", cbar=False)
    plt.title(title)
    plt.xlabel("Predicted labels")
    plt.ylabel("True labels")
    plt.show()

# Plot confusion matrix for Random Forest
plot_confusion_matrix(y_test, y_pred, title="Random Forest Confusion Matrix")

# %% [markdown]
# ###### XGBOOST MODEL

# %%
# Create an instance of the XGBoost classifier
xgb_classifier = xgb.XGBClassifier()

# Train the model on the training data
xgb_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = xgb_classifier.predict(X_test)

# %%
# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# %%
print("\nTest Set Performance:")
print(f"Accuracy: {accuracy:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1-score: {f1:.3f}")
print(f"ROC_AUC: {roc_auc:.3f}")
# Out:
# Test Set Performance:
# Accuracy: 0.847
# Precision: 0.997
# Recall: 0.847
# F1-score: 0.916
# ROC_AUC: 0.824

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(y_test, y_pred, title):
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(3, 3))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.title(title)
    plt.xlabel("Predicted labels")
    plt.ylabel("True labels")
    plt.show()

# Plot confusion matrix for Random Forest
plot_confusion_matrix(y_test, y_pred, title="XGBoost Confusion Matrix")
